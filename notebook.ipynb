# %%
import pandas as pd

# %%
data = pd.read_csv("/Users/knf792/gits/MultimodalTaxonomy/data/merged_predictions.csv")
data.columns
# Out:
# Index(['tweet_id', 'user_name', 'note', 'tweet', 'image_name', 'image_type',
#        'image_type_reasoning', 'simple_photo_people', 'classification',
#        'classification_reasoning', 'emotion', 'emotion_reasoning', 'topic',
#        'message', 'message_abstract_level_1', 'message_abstract_level_2',
#        'message_abstract_level_3', 'strategy', 'strategy_reasoning',
#        'image_misleads', 'image_misleads_reasoning', 'mechanism',
#        'mechanism_reasoning', 'sub_mechanism', 'sub_mechanism_reasoning'],
#       dtype='object')

# %%
data.drop(columns=["tweet", "user_name", "simple_photo_people"], inplace=True)
data.to_csv("/Users/knf792/gits/MultimodalTaxonomy/data/merged_predictions_just_tweet_ids.csv", index=False)
